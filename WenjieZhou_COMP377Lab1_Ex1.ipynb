# %% [markdown]
# # COMP377: AI for Software Developers
# ## Assignment 1: Linear Regression
# ### Exercise 1
#
# Name: Wenjie Zhou
#
# Student ID: 301337168
#
# Date: September 26, 2024
#
# File Name: WenjieZhou_COMP377Lab1_Ex1
#
# ### Instructions
#
# 1.  Complete the code in the cells provided according to the instructions given in the comments.
# 2.  Ensure that your code runs without errors.
# 3.  Submit your completed notebook via eCentennial.

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from ucimlrepo import fetch_ucirepo

# %% [markdown]
# ### Part 1: Data Loading

# %%
## Part 1: Data Loading ##

# Load the data from the UCI repository
real_estate_valuation = fetch_ucirepo(id=477)

# Assign the features and target to X and y
X = real_estate_valuation.data.features
y = real_estate_valuation.data.targets

# %% [markdown]
# ### Part 2: Data Preprocessing

# %%
## Part 2: Data Pre-processing ##

# Split the data by 80/20 rule due to the small size of the dataset (414 samples)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# ### Part 3: Create and Train Model

# %%
## Part 3: Model Training ###

# Create a linear regression model and fit it to the training data
linear_regression_model = LinearRegression()
linear_regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Part 4: Test Model

# %%
### Part 4: Model Evaluation ###

# Make predictions on the test data
y_pred = linear_regression_model.predict(X_test)

# Ask the user to input the attributes of a new real estate to predict its price
transaction_date = float(input("Transaction date (e.g., 2013.250 for March 2013): "))
house_age = float(input("House age (in years): "))
distance_to_MRT = float(input("Distance to the nearest MRT station (in meters): "))
num_convenience_stores = int(input("Number of convenience stores nearby: "))
latitude = float(input("Latitude: "))
longitude = float(input("Longitude: "))

# Create an input array from the user input
input_data = np.array([[transaction_date, house_age, distance_to_MRT, num_convenience_stores, latitude, longitude]])

# Predict the price based on user inputs using the trained linear regression model
predicted_price = linear_regression_model.predict(input_data)
# Out:
# c:\Program Files\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Part 5: Calculate Accuracy & Accuracy

# %%
### Part 5: Model Accuracy ###

# Calculate the mean squared error, mean absolute error, and R2 score of the model
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
print(f"R2 Score: {r2}")
# Out:
# Mean Squared Error: 53.50561912450505
# Mean Absolute Error: 5.305355690074272
# R2 Score: 0.6810580555095769

# %% [markdown]
# ### Visualization and Display (Optional)

# %%
### Visualization & Display ###

## Print Results to the Screen ###
plt.scatter(y_test, y_pred, label="Test Data", color="blue")
plt.scatter(predicted_price, predicted_price, label="User Input Prediction", color="red", marker='x', s=100)
plt.xlabel("Actual House Price")
plt.ylabel("Predicted House Price")
plt.title("UCI Actual House Price vs Predicted House Price")
plt.legend()
plt.show()

# %% [markdown]
# ### Summary and Conclusions
#
# Mean Squared Error: 53.50561912450505
#
# Mean Absolute Error: 5.305355690074272
#
# R2 Score: 0.6810580555095769
#
# Based on the results, the linear regression model developed for predicting real estate prices demonstrates good performance, especially given the limited sample size of 414. The R² score of 0.68 indicates a reasonable fit of the model to the dataset, while the Mean Squared Error and Mean Absolute Error are relatively low, suggesting accurate predictions. However, there remains potential for enhancement if a larger sample size were available, which could improve the model's robustness and predictive accuracy. Possible improvements include incorporating additional relevant features, exploring regularization techniques to prevent overfitting, identifying and addressing outliers, and utilizing more advanced regression techniques, which could lead to more reliable predictions.
